# %% [markdown]
# # MS 274 Homework 8
# In this homework, you will analyze and interpret sea ice trends in two rapidly changing marginal seas in the Antarctic Ocean: the Weddell Sea and the Amundsen Sea.
#
# #### Import the modules

# %%
# import the numpy, matplotlib, netcdf, os, and datetime modules
import numpy as np
import matplotlib.pyplot as plt
import netCDF4 as nc4
import os
import datetime as dt
import requests

# %% [markdown]
# ## Problem 8.1: Download Southern Hemisphere Sea Ice Data
# To begin this assignment, download all of the available sea ice concentration date from the National Snow and Ice Data Center.

# %% [markdown]
# #### Define a data path and download the data
# In the code block below, define a `file_folder` where you will download the sea ice data. Be sure this folder exists on your file system.

# %%
# define a path to your raster files folder 
download_folder = "D:\Remote sensing\HW_8\Data"

# %% [markdown]
# Next, copy over the **Download Data from NSIDC** notebook from Lab 8 and modify the code to download all monthly sea ice concentration data for the southern hemisphere.

# %%
# hemisphere and hemisphere code
hemisphere = 'south'
hemisphere_code = 'sh'

# initial satellite code
sat_code = 'n07'

# define the base url
base_url = 'https://noaadata.apps.nsidc.org/NOAA/G02202_V4/'+hemisphere+'/monthly/'

# make a list of URls corresponding to the file date
file_urls = []
for year in range(1979,2023):
    for month in range(1,13):

        # update satellite code when different satellites are used
        if year==1987 and month==8:
            sat_code = 'f08'
        if year==1992 and month==1:
            sat_code = 'f11'
        if year==1995 and month==10:
            sat_code = 'f13'
        if year==2008 and month==1:
            sat_code = 'f17'
        
        yr = str(year)
        mo = '{:02d}'.format(month)
        file_name = 'seaice_conc_monthly_'+hemisphere_code+'_'+yr+mo+'_'+sat_code+'_v04r00.nc'
        file_urls.append(base_url+'/'+file_name)

for i in range(len(file_urls)):
    url = file_urls[i]
    
    file_name = url.split('/')[-1]
    if file_name not in os.listdir(download_folder):
    
        print('Downloading '+file_name+' (file '+str(i+1)+' of '+str(len(file_urls))+')')
    
        output_file = os.path.join(download_folder,file_name)
    
        with requests.get(url, stream=True, allow_redirects=True) as r:
            r.raise_for_status()
            with open(output_file, 'wb') as f:                   
                for chunk in r.iter_content(chunk_size=8192):   
                    f.write(chunk)
# Out:
# Downloading seaice_conc_monthly_sh_197901_n07_v04r00.nc (file 1 of 528)
# Downloading seaice_conc_monthly_sh_197902_n07_v04r00.nc (file 2 of 528)
# Downloading seaice_conc_monthly_sh_197903_n07_v04r00.nc (file 3 of 528)
# Downloading seaice_conc_monthly_sh_197904_n07_v04r00.nc (file 4 of 528)
# Downloading seaice_conc_monthly_sh_197905_n07_v04r00.nc (file 5 of 528)
# Downloading seaice_conc_monthly_sh_197906_n07_v04r00.nc (file 6 of 528)
# Downloading seaice_conc_monthly_sh_197907_n07_v04r00.nc (file 7 of 528)
# Downloading seaice_conc_monthly_sh_197908_n07_v04r00.nc (file 8 of 528)
# Downloading seaice_conc_monthly_sh_197909_n07_v04r00.nc (file 9 of 528)
# Downloading seaice_conc_monthly_sh_197910_n07_v04r00.nc (file 10 of 528)
# Downloading seaice_conc_monthly_sh_197911_n07_v04r00.nc (file 11 of 528)
# Downloading seaice_conc_monthly_sh_197912_n07_v04r00.nc (file 12 of 528)
# Downloading seaice_conc_monthly_sh_199202_f11_v04r00.nc (file 158 of 528)
# Downloading seaice_conc_monthly_sh_199203_f11_v04r00.nc (file 159 of 528)
# Downloading seaice_conc_monthly_sh_199204_f11_v04r00.nc (file 160 of 528)
# Downloading seaice_conc_monthly_sh_199205_f11_v04r00.nc (file 161 of 528)
# Downloading seaice_conc_monthly_sh_199206_f11_v04r00.nc (file 162 of 528)
# Downloading seaice_conc_monthly_sh_199207_f11_v04r00.nc (file 163 of 528)
# Downloading seaice_conc_monthly_sh_199208_f11_v04r00.nc (file 164 of 528)
# Downloading seaice_conc_monthly_sh_199209_f11_v04r00.nc (file 165 of 528)
# Downloading seaice_conc_monthly_sh_199210_f11_v04r00.nc (file 166 of 528)
# Downloading seaice_conc_monthly_sh_199211_f11_v04r00.nc (file 167 of 528)
# Downloading seaice_conc_monthly_sh_199212_f11_v04r00.nc (file 168 of 528)
# Downloading seaice_conc_monthly_sh_199301_f11_v04r00.nc (file 169 of 528)
# Downloading seaice_conc_monthly_sh_199302_f11_v04r00.nc (file 170 of 528)
# Downloading seaice_conc_monthly_sh_199303_f11_v04r00.nc (file 171 of 528)
# Downloading seaice_conc_monthly_sh_199304_f11_v04r00.nc (file 172 of 528)
# Downloading seaice_conc_monthly_sh_199305_f11_v04r00.nc (file 173 of 528)
# Downloading seaice_conc_monthly_sh_199306_f11_v04r00.nc (file 174 of 528)
# Downloading seaice_conc_monthly_sh_199307_f11_v04r00.nc (file 175 of 528)
# Downloading seaice_conc_monthly_sh_199308_f11_v04r00.nc (file 176 of 528)
# Downloading seaice_conc_monthly_sh_199309_f11_v04r00.nc (file 177 of 528)
# Downloading seaice_conc_monthly_sh_199310_f11_v04r00.nc (file 178 of 528)
# Downloading seaice_conc_monthly_sh_199311_f11_v04r00.nc (file 179 of 528)
# Downloading seaice_conc_monthly_sh_199312_f11_v04r00.nc (file 180 of 528)
# Downloading seaice_conc_monthly_sh_199401_f11_v04r00.nc (file 181 of 528)
# Downloading seaice_conc_monthly_sh_199402_f11_v04r00.nc (file 182 of 528)
# Downloading seaice_conc_monthly_sh_199403_f11_v04r00.nc (file 183 of 528)
# Downloading seaice_conc_monthly_sh_199404_f11_v04r00.nc (file 184 of 528)
# Downloading seaice_conc_monthly_sh_199405_f11_v04r00.nc (file 185 of 528)
# Downloading seaice_conc_monthly_sh_199406_f11_v04r00.nc (file 186 of 528)
# Downloading seaice_conc_monthly_sh_199407_f11_v04r00.nc (file 187 of 528)
# Downloading seaice_conc_monthly_sh_199408_f11_v04r00.nc (file 188 of 528)
# Downloading seaice_conc_monthly_sh_199409_f11_v04r00.nc (file 189 of 528)
# Downloading seaice_conc_monthly_sh_199410_f11_v04r00.nc (file 190 of 528)
# Downloading seaice_conc_monthly_sh_199411_f11_v04r00.nc (file 191 of 528)
# Downloading seaice_conc_monthly_sh_199412_f11_v04r00.nc (file 192 of 528)
# Downloading seaice_conc_monthly_sh_199501_f11_v04r00.nc (file 193 of 528)
# Downloading seaice_conc_monthly_sh_199502_f11_v04r00.nc (file 194 of 528)
# Downloading seaice_conc_monthly_sh_199503_f11_v04r00.nc (file 195 of 528)
# Downloading seaice_conc_monthly_sh_199504_f11_v04r00.nc (file 196 of 528)
# Downloading seaice_conc_monthly_sh_199505_f11_v04r00.nc (file 197 of 528)
# Downloading seaice_conc_monthly_sh_199506_f11_v04r00.nc (file 198 of 528)
# Downloading seaice_conc_monthly_sh_199507_f11_v04r00.nc (file 199 of 528)
# Downloading seaice_conc_monthly_sh_199508_f11_v04r00.nc (file 200 of 528)
# Downloading seaice_conc_monthly_sh_199509_f11_v04r00.nc (file 201 of 528)
# Downloading seaice_conc_monthly_sh_199510_f13_v04r00.nc (file 202 of 528)
# Downloading seaice_conc_monthly_sh_199511_f13_v04r00.nc (file 203 of 528)
# Downloading seaice_conc_monthly_sh_199512_f13_v04r00.nc (file 204 of 528)
# Downloading seaice_conc_monthly_sh_199601_f13_v04r00.nc (file 205 of 528)
# Downloading seaice_conc_monthly_sh_199602_f13_v04r00.nc (file 206 of 528)
# Downloading seaice_conc_monthly_sh_199603_f13_v04r00.nc (file 207 of 528)
# Downloading seaice_conc_monthly_sh_199604_f13_v04r00.nc (file 208 of 528)
# Downloading seaice_conc_monthly_sh_199605_f13_v04r00.nc (file 209 of 528)
# Downloading seaice_conc_monthly_sh_199606_f13_v04r00.nc (file 210 of 528)
# Downloading seaice_conc_monthly_sh_199607_f13_v04r00.nc (file 211 of 528)
# Downloading seaice_conc_monthly_sh_199608_f13_v04r00.nc (file 212 of 528)
# Downloading seaice_conc_monthly_sh_199609_f13_v04r00.nc (file 213 of 528)
# Downloading seaice_conc_monthly_sh_199610_f13_v04r00.nc (file 214 of 528)
# Downloading seaice_conc_monthly_sh_199611_f13_v04r00.nc (file 215 of 528)
# Downloading seaice_conc_monthly_sh_199612_f13_v04r00.nc (file 216 of 528)
# Downloading seaice_conc_monthly_sh_199701_f13_v04r00.nc (file 217 of 528)
# Downloading seaice_conc_monthly_sh_199702_f13_v04r00.nc (file 218 of 528)
# Downloading seaice_conc_monthly_sh_199703_f13_v04r00.nc (file 219 of 528)
# Downloading seaice_conc_monthly_sh_199704_f13_v04r00.nc (file 220 of 528)
# Downloading seaice_conc_monthly_sh_199705_f13_v04r00.nc (file 221 of 528)
# Downloading seaice_conc_monthly_sh_199706_f13_v04r00.nc (file 222 of 528)
# Downloading seaice_conc_monthly_sh_199707_f13_v04r00.nc (file 223 of 528)
# Downloading seaice_conc_monthly_sh_199708_f13_v04r00.nc (file 224 of 528)
# Downloading seaice_conc_monthly_sh_199709_f13_v04r00.nc (file 225 of 528)
# Downloading seaice_conc_monthly_sh_199710_f13_v04r00.nc (file 226 of 528)
# Downloading seaice_conc_monthly_sh_199711_f13_v04r00.nc (file 227 of 528)
# Downloading seaice_conc_monthly_sh_199712_f13_v04r00.nc (file 228 of 528)
# Downloading seaice_conc_monthly_sh_199801_f13_v04r00.nc (file 229 of 528)
# Downloading seaice_conc_monthly_sh_199802_f13_v04r00.nc (file 230 of 528)
# Downloading seaice_conc_monthly_sh_199803_f13_v04r00.nc (file 231 of 528)
# Downloading seaice_conc_monthly_sh_199804_f13_v04r00.nc (file 232 of 528)
# Downloading seaice_conc_monthly_sh_199805_f13_v04r00.nc (file 233 of 528)
# Downloading seaice_conc_monthly_sh_199806_f13_v04r00.nc (file 234 of 528)
# Downloading seaice_conc_monthly_sh_199807_f13_v04r00.nc (file 235 of 528)
# Downloading seaice_conc_monthly_sh_199808_f13_v04r00.nc (file 236 of 528)
# Downloading seaice_conc_monthly_sh_199809_f13_v04r00.nc (file 237 of 528)
# Downloading seaice_conc_monthly_sh_199810_f13_v04r00.nc (file 238 of 528)
# Downloading seaice_conc_monthly_sh_199811_f13_v04r00.nc (file 239 of 528)
# Downloading seaice_conc_monthly_sh_199812_f13_v04r00.nc (file 240 of 528)
# Downloading seaice_conc_monthly_sh_199901_f13_v04r00.nc (file 241 of 528)
# Downloading seaice_conc_monthly_sh_199902_f13_v04r00.nc (file 242 of 528)
# Downloading seaice_conc_monthly_sh_199903_f13_v04r00.nc (file 243 of 528)
# Downloading seaice_conc_monthly_sh_199904_f13_v04r00.nc (file 244 of 528)
# Downloading seaice_conc_monthly_sh_199905_f13_v04r00.nc (file 245 of 528)
# Downloading seaice_conc_monthly_sh_199906_f13_v04r00.nc (file 246 of 528)
# Downloading seaice_conc_monthly_sh_199907_f13_v04r00.nc (file 247 of 528)
# Downloading seaice_conc_monthly_sh_199908_f13_v04r00.nc (file 248 of 528)
# Downloading seaice_conc_monthly_sh_199909_f13_v04r00.nc (file 249 of 528)
# Downloading seaice_conc_monthly_sh_199910_f13_v04r00.nc (file 250 of 528)
# Downloading seaice_conc_monthly_sh_199911_f13_v04r00.nc (file 251 of 528)
# Downloading seaice_conc_monthly_sh_199912_f13_v04r00.nc (file 252 of 528)
# Downloading seaice_conc_monthly_sh_200001_f13_v04r00.nc (file 253 of 528)
# Downloading seaice_conc_monthly_sh_200002_f13_v04r00.nc (file 254 of 528)
# Downloading seaice_conc_monthly_sh_200003_f13_v04r00.nc (file 255 of 528)
# Downloading seaice_conc_monthly_sh_200004_f13_v04r00.nc (file 256 of 528)
# Downloading seaice_conc_monthly_sh_200005_f13_v04r00.nc (file 257 of 528)
# Downloading seaice_conc_monthly_sh_200006_f13_v04r00.nc (file 258 of 528)
# Downloading seaice_conc_monthly_sh_200007_f13_v04r00.nc (file 259 of 528)
# Downloading seaice_conc_monthly_sh_200008_f13_v04r00.nc (file 260 of 528)
# Downloading seaice_conc_monthly_sh_200009_f13_v04r00.nc (file 261 of 528)
# Downloading seaice_conc_monthly_sh_200010_f13_v04r00.nc (file 262 of 528)
# Downloading seaice_conc_monthly_sh_200011_f13_v04r00.nc (file 263 of 528)
# Downloading seaice_conc_monthly_sh_200012_f13_v04r00.nc (file 264 of 528)
# Downloading seaice_conc_monthly_sh_200101_f13_v04r00.nc (file 265 of 528)
# Downloading seaice_conc_monthly_sh_200102_f13_v04r00.nc (file 266 of 528)
# Downloading seaice_conc_monthly_sh_200103_f13_v04r00.nc (file 267 of 528)
# Downloading seaice_conc_monthly_sh_200104_f13_v04r00.nc (file 268 of 528)
# Downloading seaice_conc_monthly_sh_200105_f13_v04r00.nc (file 269 of 528)
# Downloading seaice_conc_monthly_sh_200106_f13_v04r00.nc (file 270 of 528)
# Downloading seaice_conc_monthly_sh_200107_f13_v04r00.nc (file 271 of 528)
# Downloading seaice_conc_monthly_sh_200108_f13_v04r00.nc (file 272 of 528)
# Downloading seaice_conc_monthly_sh_200109_f13_v04r00.nc (file 273 of 528)
# Downloading seaice_conc_monthly_sh_200110_f13_v04r00.nc (file 274 of 528)
# Downloading seaice_conc_monthly_sh_200111_f13_v04r00.nc (file 275 of 528)
# Downloading seaice_conc_monthly_sh_200112_f13_v04r00.nc (file 276 of 528)
# Downloading seaice_conc_monthly_sh_200201_f13_v04r00.nc (file 277 of 528)
# Downloading seaice_conc_monthly_sh_200202_f13_v04r00.nc (file 278 of 528)
# Downloading seaice_conc_monthly_sh_200203_f13_v04r00.nc (file 279 of 528)
# Downloading seaice_conc_monthly_sh_200204_f13_v04r00.nc (file 280 of 528)
# Downloading seaice_conc_monthly_sh_200205_f13_v04r00.nc (file 281 of 528)
# Downloading seaice_conc_monthly_sh_200206_f13_v04r00.nc (file 282 of 528)
# Downloading seaice_conc_monthly_sh_200207_f13_v04r00.nc (file 283 of 528)
# Downloading seaice_conc_monthly_sh_200208_f13_v04r00.nc (file 284 of 528)
# Downloading seaice_conc_monthly_sh_200209_f13_v04r00.nc (file 285 of 528)
# Downloading seaice_conc_monthly_sh_200210_f13_v04r00.nc (file 286 of 528)
# Downloading seaice_conc_monthly_sh_200211_f13_v04r00.nc (file 287 of 528)
# Downloading seaice_conc_monthly_sh_200212_f13_v04r00.nc (file 288 of 528)
# Downloading seaice_conc_monthly_sh_200301_f13_v04r00.nc (file 289 of 528)
# Downloading seaice_conc_monthly_sh_200302_f13_v04r00.nc (file 290 of 528)
# Downloading seaice_conc_monthly_sh_200303_f13_v04r00.nc (file 291 of 528)
# Downloading seaice_conc_monthly_sh_200304_f13_v04r00.nc (file 292 of 528)
# Downloading seaice_conc_monthly_sh_200305_f13_v04r00.nc (file 293 of 528)
# Downloading seaice_conc_monthly_sh_200306_f13_v04r00.nc (file 294 of 528)
# Downloading seaice_conc_monthly_sh_200307_f13_v04r00.nc (file 295 of 528)
# Downloading seaice_conc_monthly_sh_200308_f13_v04r00.nc (file 296 of 528)
# Downloading seaice_conc_monthly_sh_200309_f13_v04r00.nc (file 297 of 528)
# Downloading seaice_conc_monthly_sh_200310_f13_v04r00.nc (file 298 of 528)
# Downloading seaice_conc_monthly_sh_200311_f13_v04r00.nc (file 299 of 528)
# Downloading seaice_conc_monthly_sh_200312_f13_v04r00.nc (file 300 of 528)
# Downloading seaice_conc_monthly_sh_200401_f13_v04r00.nc (file 301 of 528)
# Downloading seaice_conc_monthly_sh_200402_f13_v04r00.nc (file 302 of 528)
# Downloading seaice_conc_monthly_sh_200403_f13_v04r00.nc (file 303 of 528)
# Downloading seaice_conc_monthly_sh_200404_f13_v04r00.nc (file 304 of 528)
# Downloading seaice_conc_monthly_sh_200405_f13_v04r00.nc (file 305 of 528)
# Downloading seaice_conc_monthly_sh_200406_f13_v04r00.nc (file 306 of 528)
# Downloading seaice_conc_monthly_sh_200407_f13_v04r00.nc (file 307 of 528)
# Downloading seaice_conc_monthly_sh_200408_f13_v04r00.nc (file 308 of 528)
# Downloading seaice_conc_monthly_sh_200409_f13_v04r00.nc (file 309 of 528)
# Downloading seaice_conc_monthly_sh_200410_f13_v04r00.nc (file 310 of 528)
# Downloading seaice_conc_monthly_sh_200411_f13_v04r00.nc (file 311 of 528)
# Downloading seaice_conc_monthly_sh_200412_f13_v04r00.nc (file 312 of 528)
# Downloading seaice_conc_monthly_sh_200501_f13_v04r00.nc (file 313 of 528)
# Downloading seaice_conc_monthly_sh_200502_f13_v04r00.nc (file 314 of 528)
# Downloading seaice_conc_monthly_sh_200503_f13_v04r00.nc (file 315 of 528)
# Downloading seaice_conc_monthly_sh_200504_f13_v04r00.nc (file 316 of 528)
# Downloading seaice_conc_monthly_sh_200505_f13_v04r00.nc (file 317 of 528)
# Downloading seaice_conc_monthly_sh_200506_f13_v04r00.nc (file 318 of 528)
# Downloading seaice_conc_monthly_sh_200507_f13_v04r00.nc (file 319 of 528)
# Downloading seaice_conc_monthly_sh_200508_f13_v04r00.nc (file 320 of 528)
# Downloading seaice_conc_monthly_sh_200509_f13_v04r00.nc (file 321 of 528)
# Downloading seaice_conc_monthly_sh_200510_f13_v04r00.nc (file 322 of 528)
# Downloading seaice_conc_monthly_sh_200511_f13_v04r00.nc (file 323 of 528)
# Downloading seaice_conc_monthly_sh_200512_f13_v04r00.nc (file 324 of 528)
# Downloading seaice_conc_monthly_sh_200601_f13_v04r00.nc (file 325 of 528)
# Downloading seaice_conc_monthly_sh_200602_f13_v04r00.nc (file 326 of 528)
# Downloading seaice_conc_monthly_sh_200603_f13_v04r00.nc (file 327 of 528)
# Downloading seaice_conc_monthly_sh_200604_f13_v04r00.nc (file 328 of 528)
# Downloading seaice_conc_monthly_sh_200605_f13_v04r00.nc (file 329 of 528)
# Downloading seaice_conc_monthly_sh_200606_f13_v04r00.nc (file 330 of 528)
# Downloading seaice_conc_monthly_sh_200607_f13_v04r00.nc (file 331 of 528)
# Downloading seaice_conc_monthly_sh_200608_f13_v04r00.nc (file 332 of 528)
# Downloading seaice_conc_monthly_sh_200609_f13_v04r00.nc (file 333 of 528)
# Downloading seaice_conc_monthly_sh_200610_f13_v04r00.nc (file 334 of 528)
# Downloading seaice_conc_monthly_sh_200611_f13_v04r00.nc (file 335 of 528)
# Downloading seaice_conc_monthly_sh_200612_f13_v04r00.nc (file 336 of 528)
# Downloading seaice_conc_monthly_sh_200701_f13_v04r00.nc (file 337 of 528)
# Downloading seaice_conc_monthly_sh_200702_f13_v04r00.nc (file 338 of 528)
# Downloading seaice_conc_monthly_sh_200703_f13_v04r00.nc (file 339 of 528)
# Downloading seaice_conc_monthly_sh_200704_f13_v04r00.nc (file 340 of 528)
# Downloading seaice_conc_monthly_sh_200705_f13_v04r00.nc (file 341 of 528)
# Downloading seaice_conc_monthly_sh_200706_f13_v04r00.nc (file 342 of 528)
# Downloading seaice_conc_monthly_sh_200707_f13_v04r00.nc (file 343 of 528)
# Downloading seaice_conc_monthly_sh_200708_f13_v04r00.nc (file 344 of 528)
# Downloading seaice_conc_monthly_sh_200709_f13_v04r00.nc (file 345 of 528)
# Downloading seaice_conc_monthly_sh_200710_f13_v04r00.nc (file 346 of 528)
# Downloading seaice_conc_monthly_sh_200711_f13_v04r00.nc (file 347 of 528)
# Downloading seaice_conc_monthly_sh_200712_f13_v04r00.nc (file 348 of 528)
# Downloading seaice_conc_monthly_sh_200801_f17_v04r00.nc (file 349 of 528)
# Downloading seaice_conc_monthly_sh_200802_f17_v04r00.nc (file 350 of 528)
# Downloading seaice_conc_monthly_sh_200803_f17_v04r00.nc (file 351 of 528)
# Downloading seaice_conc_monthly_sh_200804_f17_v04r00.nc (file 352 of 528)
# Downloading seaice_conc_monthly_sh_200805_f17_v04r00.nc (file 353 of 528)
# Downloading seaice_conc_monthly_sh_200806_f17_v04r00.nc (file 354 of 528)
# Downloading seaice_conc_monthly_sh_200807_f17_v04r00.nc (file 355 of 528)
# Downloading seaice_conc_monthly_sh_200808_f17_v04r00.nc (file 356 of 528)
# Downloading seaice_conc_monthly_sh_200809_f17_v04r00.nc (file 357 of 528)
# Downloading seaice_conc_monthly_sh_200810_f17_v04r00.nc (file 358 of 528)
# Downloading seaice_conc_monthly_sh_200811_f17_v04r00.nc (file 359 of 528)
# Downloading seaice_conc_monthly_sh_200812_f17_v04r00.nc (file 360 of 528)
# Downloading seaice_conc_monthly_sh_200901_f17_v04r00.nc (file 361 of 528)
# Downloading seaice_conc_monthly_sh_200902_f17_v04r00.nc (file 362 of 528)
# Downloading seaice_conc_monthly_sh_200903_f17_v04r00.nc (file 363 of 528)
# Downloading seaice_conc_monthly_sh_200904_f17_v04r00.nc (file 364 of 528)
# Downloading seaice_conc_monthly_sh_200905_f17_v04r00.nc (file 365 of 528)
# Downloading seaice_conc_monthly_sh_200906_f17_v04r00.nc (file 366 of 528)
# Downloading seaice_conc_monthly_sh_200907_f17_v04r00.nc (file 367 of 528)
# Downloading seaice_conc_monthly_sh_200908_f17_v04r00.nc (file 368 of 528)
# Downloading seaice_conc_monthly_sh_200909_f17_v04r00.nc (file 369 of 528)
# Downloading seaice_conc_monthly_sh_200910_f17_v04r00.nc (file 370 of 528)
# Downloading seaice_conc_monthly_sh_200911_f17_v04r00.nc (file 371 of 528)
# Downloading seaice_conc_monthly_sh_200912_f17_v04r00.nc (file 372 of 528)
# Downloading seaice_conc_monthly_sh_201001_f17_v04r00.nc (file 373 of 528)
# Downloading seaice_conc_monthly_sh_201002_f17_v04r00.nc (file 374 of 528)
# Downloading seaice_conc_monthly_sh_201003_f17_v04r00.nc (file 375 of 528)
# Downloading seaice_conc_monthly_sh_201004_f17_v04r00.nc (file 376 of 528)
# Downloading seaice_conc_monthly_sh_201005_f17_v04r00.nc (file 377 of 528)
# Downloading seaice_conc_monthly_sh_201006_f17_v04r00.nc (file 378 of 528)
# Downloading seaice_conc_monthly_sh_201007_f17_v04r00.nc (file 379 of 528)
# Downloading seaice_conc_monthly_sh_201008_f17_v04r00.nc (file 380 of 528)
# Downloading seaice_conc_monthly_sh_201009_f17_v04r00.nc (file 381 of 528)
# Downloading seaice_conc_monthly_sh_201010_f17_v04r00.nc (file 382 of 528)
# Downloading seaice_conc_monthly_sh_201011_f17_v04r00.nc (file 383 of 528)
# Downloading seaice_conc_monthly_sh_201012_f17_v04r00.nc (file 384 of 528)
# Downloading seaice_conc_monthly_sh_201101_f17_v04r00.nc (file 385 of 528)
# Downloading seaice_conc_monthly_sh_201102_f17_v04r00.nc (file 386 of 528)
# Downloading seaice_conc_monthly_sh_201103_f17_v04r00.nc (file 387 of 528)
# Downloading seaice_conc_monthly_sh_201104_f17_v04r00.nc (file 388 of 528)
# Downloading seaice_conc_monthly_sh_201105_f17_v04r00.nc (file 389 of 528)
# Downloading seaice_conc_monthly_sh_201106_f17_v04r00.nc (file 390 of 528)
# Downloading seaice_conc_monthly_sh_201107_f17_v04r00.nc (file 391 of 528)
# Downloading seaice_conc_monthly_sh_201108_f17_v04r00.nc (file 392 of 528)
# Downloading seaice_conc_monthly_sh_201109_f17_v04r00.nc (file 393 of 528)
# Downloading seaice_conc_monthly_sh_201110_f17_v04r00.nc (file 394 of 528)
# Downloading seaice_conc_monthly_sh_201111_f17_v04r00.nc (file 395 of 528)
# Downloading seaice_conc_monthly_sh_201112_f17_v04r00.nc (file 396 of 528)
# Downloading seaice_conc_monthly_sh_201201_f17_v04r00.nc (file 397 of 528)
# Downloading seaice_conc_monthly_sh_201202_f17_v04r00.nc (file 398 of 528)
# Downloading seaice_conc_monthly_sh_201203_f17_v04r00.nc (file 399 of 528)
# Downloading seaice_conc_monthly_sh_201204_f17_v04r00.nc (file 400 of 528)
# Downloading seaice_conc_monthly_sh_201205_f17_v04r00.nc (file 401 of 528)
# Downloading seaice_conc_monthly_sh_201206_f17_v04r00.nc (file 402 of 528)
# Downloading seaice_conc_monthly_sh_201207_f17_v04r00.nc (file 403 of 528)
# Downloading seaice_conc_monthly_sh_201208_f17_v04r00.nc (file 404 of 528)
# Downloading seaice_conc_monthly_sh_201209_f17_v04r00.nc (file 405 of 528)
# Downloading seaice_conc_monthly_sh_201210_f17_v04r00.nc (file 406 of 528)
# Downloading seaice_conc_monthly_sh_201211_f17_v04r00.nc (file 407 of 528)
# Downloading seaice_conc_monthly_sh_201212_f17_v04r00.nc (file 408 of 528)
# Downloading seaice_conc_monthly_sh_201301_f17_v04r00.nc (file 409 of 528)
# Downloading seaice_conc_monthly_sh_201302_f17_v04r00.nc (file 410 of 528)
# Downloading seaice_conc_monthly_sh_201303_f17_v04r00.nc (file 411 of 528)
# Downloading seaice_conc_monthly_sh_201304_f17_v04r00.nc (file 412 of 528)
# Downloading seaice_conc_monthly_sh_201305_f17_v04r00.nc (file 413 of 528)
# Downloading seaice_conc_monthly_sh_201306_f17_v04r00.nc (file 414 of 528)
# Downloading seaice_conc_monthly_sh_201307_f17_v04r00.nc (file 415 of 528)
# Downloading seaice_conc_monthly_sh_201308_f17_v04r00.nc (file 416 of 528)
# Downloading seaice_conc_monthly_sh_201309_f17_v04r00.nc (file 417 of 528)
# Downloading seaice_conc_monthly_sh_201310_f17_v04r00.nc (file 418 of 528)
# Downloading seaice_conc_monthly_sh_201311_f17_v04r00.nc (file 419 of 528)
# Downloading seaice_conc_monthly_sh_201312_f17_v04r00.nc (file 420 of 528)
# Downloading seaice_conc_monthly_sh_201401_f17_v04r00.nc (file 421 of 528)
# Downloading seaice_conc_monthly_sh_201402_f17_v04r00.nc (file 422 of 528)
# Downloading seaice_conc_monthly_sh_201403_f17_v04r00.nc (file 423 of 528)
# Downloading seaice_conc_monthly_sh_201404_f17_v04r00.nc (file 424 of 528)
# Downloading seaice_conc_monthly_sh_201405_f17_v04r00.nc (file 425 of 528)
# Downloading seaice_conc_monthly_sh_201406_f17_v04r00.nc (file 426 of 528)
# Downloading seaice_conc_monthly_sh_201407_f17_v04r00.nc (file 427 of 528)
# Downloading seaice_conc_monthly_sh_201408_f17_v04r00.nc (file 428 of 528)
# Downloading seaice_conc_monthly_sh_201409_f17_v04r00.nc (file 429 of 528)
# Downloading seaice_conc_monthly_sh_201410_f17_v04r00.nc (file 430 of 528)
# Downloading seaice_conc_monthly_sh_201411_f17_v04r00.nc (file 431 of 528)
# Downloading seaice_conc_monthly_sh_201412_f17_v04r00.nc (file 432 of 528)
# Downloading seaice_conc_monthly_sh_201501_f17_v04r00.nc (file 433 of 528)
# Downloading seaice_conc_monthly_sh_201502_f17_v04r00.nc (file 434 of 528)
# Downloading seaice_conc_monthly_sh_201503_f17_v04r00.nc (file 435 of 528)
# Downloading seaice_conc_monthly_sh_201504_f17_v04r00.nc (file 436 of 528)
# Downloading seaice_conc_monthly_sh_201505_f17_v04r00.nc (file 437 of 528)
# Downloading seaice_conc_monthly_sh_201506_f17_v04r00.nc (file 438 of 528)
# Downloading seaice_conc_monthly_sh_201507_f17_v04r00.nc (file 439 of 528)
# Downloading seaice_conc_monthly_sh_201508_f17_v04r00.nc (file 440 of 528)
# Downloading seaice_conc_monthly_sh_201509_f17_v04r00.nc (file 441 of 528)
# Downloading seaice_conc_monthly_sh_201510_f17_v04r00.nc (file 442 of 528)
# Downloading seaice_conc_monthly_sh_201511_f17_v04r00.nc (file 443 of 528)
# Downloading seaice_conc_monthly_sh_201512_f17_v04r00.nc (file 444 of 528)
# Downloading seaice_conc_monthly_sh_201601_f17_v04r00.nc (file 445 of 528)
# Downloading seaice_conc_monthly_sh_201602_f17_v04r00.nc (file 446 of 528)
# Downloading seaice_conc_monthly_sh_201603_f17_v04r00.nc (file 447 of 528)
# Downloading seaice_conc_monthly_sh_201604_f17_v04r00.nc (file 448 of 528)
# Downloading seaice_conc_monthly_sh_201605_f17_v04r00.nc (file 449 of 528)
# Downloading seaice_conc_monthly_sh_201606_f17_v04r00.nc (file 450 of 528)
# Downloading seaice_conc_monthly_sh_201607_f17_v04r00.nc (file 451 of 528)
# Downloading seaice_conc_monthly_sh_201608_f17_v04r00.nc (file 452 of 528)
# Downloading seaice_conc_monthly_sh_201609_f17_v04r00.nc (file 453 of 528)
# Downloading seaice_conc_monthly_sh_201610_f17_v04r00.nc (file 454 of 528)
# Downloading seaice_conc_monthly_sh_201611_f17_v04r00.nc (file 455 of 528)
# Downloading seaice_conc_monthly_sh_201612_f17_v04r00.nc (file 456 of 528)
# Downloading seaice_conc_monthly_sh_201701_f17_v04r00.nc (file 457 of 528)
# Downloading seaice_conc_monthly_sh_201702_f17_v04r00.nc (file 458 of 528)
# Downloading seaice_conc_monthly_sh_201703_f17_v04r00.nc (file 459 of 528)
# Downloading seaice_conc_monthly_sh_201704_f17_v04r00.nc (file 460 of 528)
# Downloading seaice_conc_monthly_sh_201705_f17_v04r00.nc (file 461 of 528)
# Downloading seaice_conc_monthly_sh_201706_f17_v04r00.nc (file 462 of 528)
# Downloading seaice_conc_monthly_sh_201707_f17_v04r00.nc (file 463 of 528)
# Downloading seaice_conc_monthly_sh_201708_f17_v04r00.nc (file 464 of 528)
# Downloading seaice_conc_monthly_sh_201709_f17_v04r00.nc (file 465 of 528)
# Downloading seaice_conc_monthly_sh_201710_f17_v04r00.nc (file 466 of 528)
# Downloading seaice_conc_monthly_sh_201711_f17_v04r00.nc (file 467 of 528)
# Downloading seaice_conc_monthly_sh_201712_f17_v04r00.nc (file 468 of 528)
# Downloading seaice_conc_monthly_sh_201801_f17_v04r00.nc (file 469 of 528)
# Downloading seaice_conc_monthly_sh_201802_f17_v04r00.nc (file 470 of 528)
# Downloading seaice_conc_monthly_sh_201803_f17_v04r00.nc (file 471 of 528)
# Downloading seaice_conc_monthly_sh_201804_f17_v04r00.nc (file 472 of 528)
# Downloading seaice_conc_monthly_sh_201805_f17_v04r00.nc (file 473 of 528)
# Downloading seaice_conc_monthly_sh_201806_f17_v04r00.nc (file 474 of 528)
# Downloading seaice_conc_monthly_sh_201807_f17_v04r00.nc (file 475 of 528)
# Downloading seaice_conc_monthly_sh_201808_f17_v04r00.nc (file 476 of 528)
# Downloading seaice_conc_monthly_sh_201809_f17_v04r00.nc (file 477 of 528)
# Downloading seaice_conc_monthly_sh_201810_f17_v04r00.nc (file 478 of 528)
# Downloading seaice_conc_monthly_sh_201811_f17_v04r00.nc (file 479 of 528)
# Downloading seaice_conc_monthly_sh_201812_f17_v04r00.nc (file 480 of 528)
# Downloading seaice_conc_monthly_sh_201901_f17_v04r00.nc (file 481 of 528)
# Downloading seaice_conc_monthly_sh_201902_f17_v04r00.nc (file 482 of 528)
# Downloading seaice_conc_monthly_sh_201903_f17_v04r00.nc (file 483 of 528)
# Downloading seaice_conc_monthly_sh_201904_f17_v04r00.nc (file 484 of 528)
# Downloading seaice_conc_monthly_sh_201905_f17_v04r00.nc (file 485 of 528)
# Downloading seaice_conc_monthly_sh_201906_f17_v04r00.nc (file 486 of 528)
# Downloading seaice_conc_monthly_sh_201907_f17_v04r00.nc (file 487 of 528)
# Downloading seaice_conc_monthly_sh_201908_f17_v04r00.nc (file 488 of 528)
# Downloading seaice_conc_monthly_sh_201909_f17_v04r00.nc (file 489 of 528)
# Downloading seaice_conc_monthly_sh_201910_f17_v04r00.nc (file 490 of 528)
# Downloading seaice_conc_monthly_sh_201911_f17_v04r00.nc (file 491 of 528)
# Downloading seaice_conc_monthly_sh_201912_f17_v04r00.nc (file 492 of 528)
# Downloading seaice_conc_monthly_sh_202001_f17_v04r00.nc (file 493 of 528)
# Downloading seaice_conc_monthly_sh_202002_f17_v04r00.nc (file 494 of 528)
# Downloading seaice_conc_monthly_sh_202003_f17_v04r00.nc (file 495 of 528)
# Downloading seaice_conc_monthly_sh_202004_f17_v04r00.nc (file 496 of 528)
# Downloading seaice_conc_monthly_sh_202005_f17_v04r00.nc (file 497 of 528)
# Downloading seaice_conc_monthly_sh_202006_f17_v04r00.nc (file 498 of 528)
# Downloading seaice_conc_monthly_sh_202007_f17_v04r00.nc (file 499 of 528)
# Downloading seaice_conc_monthly_sh_202008_f17_v04r00.nc (file 500 of 528)
# Downloading seaice_conc_monthly_sh_202009_f17_v04r00.nc (file 501 of 528)
# Downloading seaice_conc_monthly_sh_202010_f17_v04r00.nc (file 502 of 528)
# Downloading seaice_conc_monthly_sh_202011_f17_v04r00.nc (file 503 of 528)
# Downloading seaice_conc_monthly_sh_202012_f17_v04r00.nc (file 504 of 528)
# Downloading seaice_conc_monthly_sh_202101_f17_v04r00.nc (file 505 of 528)
# Downloading seaice_conc_monthly_sh_202102_f17_v04r00.nc (file 506 of 528)
# Downloading seaice_conc_monthly_sh_202103_f17_v04r00.nc (file 507 of 528)
# Downloading seaice_conc_monthly_sh_202104_f17_v04r00.nc (file 508 of 528)
# Downloading seaice_conc_monthly_sh_202105_f17_v04r00.nc (file 509 of 528)
# Downloading seaice_conc_monthly_sh_202106_f17_v04r00.nc (file 510 of 528)
# Downloading seaice_conc_monthly_sh_202107_f17_v04r00.nc (file 511 of 528)
# Downloading seaice_conc_monthly_sh_202108_f17_v04r00.nc (file 512 of 528)
# Downloading seaice_conc_monthly_sh_202109_f17_v04r00.nc (file 513 of 528)
# Downloading seaice_conc_monthly_sh_202110_f17_v04r00.nc (file 514 of 528)
# Downloading seaice_conc_monthly_sh_202111_f17_v04r00.nc (file 515 of 528)
# Downloading seaice_conc_monthly_sh_202112_f17_v04r00.nc (file 516 of 528)
# Downloading seaice_conc_monthly_sh_202201_f17_v04r00.nc (file 517 of 528)
# Downloading seaice_conc_monthly_sh_202202_f17_v04r00.nc (file 518 of 528)
# Downloading seaice_conc_monthly_sh_202203_f17_v04r00.nc (file 519 of 528)
# Downloading seaice_conc_monthly_sh_202204_f17_v04r00.nc (file 520 of 528)
# Downloading seaice_conc_monthly_sh_202205_f17_v04r00.nc (file 521 of 528)
# Downloading seaice_conc_monthly_sh_202206_f17_v04r00.nc (file 522 of 528)
# Downloading seaice_conc_monthly_sh_202207_f17_v04r00.nc (file 523 of 528)
# Downloading seaice_conc_monthly_sh_202208_f17_v04r00.nc (file 524 of 528)
# Downloading seaice_conc_monthly_sh_202209_f17_v04r00.nc (file 525 of 528)
# Downloading seaice_conc_monthly_sh_202210_f17_v04r00.nc (file 526 of 528)
# Downloading seaice_conc_monthly_sh_202211_f17_v04r00.nc (file 527 of 528)
# Downloading seaice_conc_monthly_sh_202212_f17_v04r00.nc (file 528 of 528)

# %% [markdown]
# ## Problem 8.2: Make Timeseries of Sea Ice in the Weddell Sea and the Amundsen Sea
# Chapter 9 of the most recent IPCC Assessment Report, found [HERE](https://www.ipcc.ch/report/ar6/wg1/chapter/chapter-9/), describes recent trends in the Weddell Sea and the Amundsen Sea. These two regions can be roughly defined by the boxes with the extents defined below:

# %%
# Weddell Sea
min_x_weddell = 1748344
min_y_weddell = -2139981
max_x_weddell = 2626968
max_y_weddell = -581133

# Amundsen Sea
min_x_amundsen = -1635773
min_y_amundsen = -1816875
max_x_amundsen = -1352346
max_y_amundsen = -558459

# %% [markdown]
# The above coordinates are provided in the *NSIDC Sea Ice Polar Stereographic South* projection (EPSG: 3412). This is the same projection as for the x and y grids distriburted with the Southern Hemisphere sea ice data.
#
# ### Create two timeseries
# Using the files downloaded in Problem 8.1, generate two timeseries of sea ice area - one for the Weddell Sea and one for the Amundsen Sea.

# %%
#this is four loop for ws
#first define the bounds for ws
# make a file path to one of the nc files
file_path = os.path.join(download_folder, 'seaice_conc_monthly_sh_197901_n07_v04r00.nc' )
# open the file and read in the sea ice variable to a 2D numpy grid
ds = nc4.Dataset(file_path)
x = np.array(ds.variables['xgrid'])
y = np.array(ds.variables['ygrid'])
sea_ice = np.array(ds.variables['nsidc_nt_seaice_conc_monthly'])
ds.close()

# find the indices of the box bounds in the x and y grids
min_col_WS = np.argmin(np.abs(x-min_x_weddell))
max_col_WS = np.argmin(np.abs(x-max_x_weddell))
max_row_WS = np.argmin(np.abs(y-min_y_weddell))
min_row_WS = np.argmin(np.abs(y-max_y_weddell))

# make a sorted file list of all the sea ice nc files
file_list_sea_ice = []

# write a for loop to loop through the files
for file_name_sea_ice in os.listdir(download_folder):
    if file_name_sea_ice[-3:] == '.nc':
        if 'seaice' in file_name_sea_ice:
            file_list_sea_ice.append(file_name_sea_ice) #don't really need the if seaice but im keeping it

# sort the file list
file_list_sea_ice.sort()

# Make empty lists to store dates and sea ice values
date_list_WS = []
seaice_values_WS = []

# # loop through all of the files in the file list
for file_name_sea_ice in file_list_sea_ice:
    # Split the file name and retrieve the year and month strings
    file_parts = file_name_sea_ice.split('_')
    year = file_parts[4][:4]  # First 4 characters are the year
    month = file_parts[4][4:6]  # Characters 5 and 6 are the month
    
    # Make a string for the middle day of the month (15)
    day = '01'
    
    # Join the year, month, and day strings with dashes and add to the date_list
    date_string = year + '-' + month + '-' + day 

    # make a file path to one of the nc files
    file_path = os.path.join(download_folder, file_name_sea_ice)

    # open the file and read in the sea ice variable to a 2D numpy grid
    ds = nc4.Dataset(file_path)
    sea_ice_WS = np.array(ds.variables['nsidc_nt_seaice_conc_monthly'])
    ds.close()
    #does not incldue x and y because of chunk 42
    # take only the "first timestep" of the seaice grid
    sea_ice_WS = sea_ice_WS[0, :, :]

    # subset the grid and find the area of sea ice in the subset
    sea_ice_subset_WS = sea_ice_WS[min_row_WS:max_row_WS, min_col_WS:max_col_WS]

    # compute the total area of seaice in this grid
    sea_ice_raveled_WS = sea_ice_subset_WS.ravel()
    sea_ice_filtered_WS = sea_ice_raveled_WS[sea_ice_raveled_WS < 2]
    area=np.sum(sea_ice_filtered_WS*25*25)
    # if the sea ice area value is valid (>0), add the date to the date list
    # and the value to the value list 
    if area > 0: 
        date_list_WS.append(date_string)
        seaice_values_WS.append(area)



# After the loop, convert the date_list to a NumPy array with dtype='datetime64'
date_array_WS = np.array(date_list_WS, dtype='datetime64')

# %%
#this is four lopp for AM
#first define the bounds for AM
# make a file path to one of the nc files
file_path = os.path.join(download_folder, 'seaice_conc_monthly_sh_197901_n07_v04r00.nc' )
# open the file and read in the sea ice variable to a 2D numpy grid
ds = nc4.Dataset(file_path)
x = np.array(ds.variables['xgrid'])
y = np.array(ds.variables['ygrid'])
sea_ice = np.array(ds.variables['nsidc_nt_seaice_conc_monthly'])
ds.close()

# find the indices of the box bounds in the x and y grids
min_col_AM = np.argmin(np.abs(x-min_x_amundsen))
max_col_AM = np.argmin(np.abs(x-max_x_amundsen))
max_row_AM = np.argmin(np.abs(y-min_y_amundsen))
min_row_AM = np.argmin(np.abs(y-max_y_amundsen))

# make a sorted file list of all the sea ice nc files
file_list_sea_ice = []

# write a for loop to loop through the files
for file_name_sea_ice in os.listdir(download_folder):
    if file_name_sea_ice[-3:] == '.nc':
        if 'seaice' in file_name_sea_ice:
            file_list_sea_ice.append(file_name_sea_ice) #don't really need the if seaice but im keeping it

# sort the file list
file_list_sea_ice.sort()

# Make empty lists to store dates and sea ice values
date_list_AM = []
seaice_values_AM = []

# # loop through all of the files in the file list
for file_name_sea_ice in file_list_sea_ice:
    # Split the file name and retrieve the year and month strings
    file_parts = file_name_sea_ice.split('_')
    year = file_parts[4][:4]  # First 4 characters are the year
    month = file_parts[4][4:6]  # Characters 5 and 6 are the month
    
    # Make a string for the middle day of the month (15)
    day = '01'
    
    # Join the year, month, and day strings with dashes and add to the date_list
    date_string = year + '-' + month + '-' + day 

    # make a file path to one of the nc files
    file_path = os.path.join(download_folder, file_name_sea_ice)

    # open the file and read in the sea ice variable to a 2D numpy grid
    ds = nc4.Dataset(file_path)
    sea_ice_AM = np.array(ds.variables['nsidc_nt_seaice_conc_monthly'])
    ds.close()
    #does not incldue x and y because of chunk 42
    # take only the "first timestep" of the seaice grid
    sea_ice_AM = sea_ice_AM[0, :, :]

    # subset the grid and find the area of sea ice in the subset
    sea_ice_subset_AM = sea_ice_AM[min_row_AM:max_row_AM, min_col_AM:max_col_AM]

    # compute the total area of seaice in this grid
    sea_ice_raveled_AM = sea_ice_subset_AM.ravel()
    sea_ice_filtered_AM = sea_ice_raveled_AM[sea_ice_raveled_AM < 2]
    area=np.sum(sea_ice_filtered_AM*25*25)
    # if the sea ice area value is valid (>0), add the date to the date list
    # and the value to the value list 
    if area > 0: 
        date_list_AM.append(date_string)
        seaice_values_AM.append(area)



# After the loop, convert the date_list to a NumPy array with dtype='datetime64'
date_array_AM = np.array(date_list_AM, dtype='datetime64')

# %%
#now create timeseries 
fig = plt.figure(figsize=(11,5))

# make a plot of the sea ice values vs the date array
plt.plot(date_array_AM, seaice_values_AM, label = 'Amundsen', color = 'green')
plt.plot(date_array_WS, seaice_values_WS, label = "Waddell")

# label the y axis
plt.ylabel('Sea ice area (km$^2$)')
plt.xlabel('Time (year)')

# show the figure
plt.legend()
plt.show()

# %% [markdown]
# ## Problem 8.3: Subset the timeseries to March
# In the southern hemisphere, the sea ice minimum occurs around March of each year. Create two timeseries subsets from the Weddell and Amundsen timeseries for March values only. Store the dates as decimal years so that trends can be computed in the next step

# %%
# subset set for march first for WS
mar_dates_WS = []
mar_values_WS = []

# loop through the full date array
for i in range(len(date_array_WS)):
    
    date = date_array_WS[i]
    value = seaice_values_WS[i]
    
    # convert the date to a datetime object
    date_datetime = date.astype(dt.datetime)
    
    # if the month is September, add it and its value to the list
    if date_datetime.month == 3: #in[3,4,5]
        mar_dates_WS.append(date)
        mar_values_WS.append(value)
                            
# subset set for march first for AM
mar_dates_AM = []
mar_values_AM = []

# loop through the full date array
for i in range(len(date_array_AM)):
    
    date = date_array_AM[i]
    value = seaice_values_AM[i]
    
    # convert the date to a datetime object
    date_datetime = date.astype(dt.datetime)
    
    # if the month is September, add it and its value to the list
    if date_datetime.month == 3: #in[3,4,5]
        mar_dates_AM.append(date)
        mar_values_AM.append(value)

# %%
#in decimal format 
# define a function to turn a date, given by year, month, and day, into a decimal year
def YMD_to_DecYr(year,month,day):
    
    # define a date object using the datetime module
    date = dt.datetime(year,month,day)

    # define the start in ordinal units (days since ...)
    start = dt.date(date.year, 1, 1).toordinal()

    # compute the year_length in ordinal units (365 or 366)
    year_length = dt.date(date.year+1, 1, 1).toordinal() - start

    # compute the fraction based on the date
    decimal_fraction = float(date.toordinal() - start) / year_length

    # compute the decimal year
    dec_yr = year+decimal_fraction
    return(dec_yr)
    
#WS in march
mar_decyrs_WS = []
# loop through the sept date values and fill in the decimal years list
for date in mar_dates_WS:
    year = int(str(date) [:4])
    month = int(str(date) [5:7])
    day = int(str(date) [8:10])
    decyr = YMD_to_DecYr(year,month,day)
    mar_decyrs_WS.append(decyr)
    
#AM in march
mar_decyrs_AM = []
# loop through the sept date values and fill in the decimal years list
for date in mar_dates_AM:
    year = int(str(date) [:4])
    month = int(str(date) [5:7])
    day = int(str(date) [8:10])
    decyr = YMD_to_DecYr(year,month,day)
    mar_decyrs_AM.append(decyr)

# %% [markdown]
# ## Problem 8.4: Compute the March trends of Sea Ice in the Weddell and Amundsen Seas
# Compute the trends in sea ice area in March for the Weddell Sea and the Amundsen Sea. (Be sure to convert the dates to decimal years if you have not done so already.)

# %%
# use numpy's polyfit function to compute the weddell trend
p = np.polyfit(mar_decyrs_WS, mar_values_WS, 1)
print(p)

# the slope value is the first value
slope_WS = p[0]

# the intercept is the second value
intercept_WS = p[1]

# compute the values of the best fit line 
# for the september decyr values
best_fit_line_WS = slope_WS*np.array(mar_decyrs_WS) + intercept_WS
# Out:
# [ 8.74409955e+02 -1.66284768e+06]

# %%
# use numpy's polyfit function to compute the amundsen trend
p = np.polyfit(mar_decyrs_AM, mar_values_AM, 1)
print(p)

# the slope value is the first value
slope_AM = p[0]

# the intercept is the second value
intercept_AM = p[1]

# compute the values of the best fit line 
# for the september decyr values
best_fit_line_AM = slope_AM*np.array(mar_decyrs_AM) + intercept_AM
# Out:
# [-1.51308703e+03  3.09921013e+06]

# %% [markdown]
# ## Problem 8.5: Plot the March Sea Ice Timeseries for the Weddell Sea and Amundsen Sea
# Plot the March sea ice timeseries on two separate plots. In addition, plot the trend lines and include a label in the legend which shows the trend in sea ice area. Be sure to add labels to the axis and gridlines to your plot.

# %%
# make a figure with two subplot to show the timeseries and trends
fig = plt.figure(figsize=(15,4))

# make a plot of the sea ice values vs the date array
plt.subplot(1,2,1)
plt.plot(mar_dates_WS, mar_values_WS, color = 'blue')
plt.plot(mar_dates_WS, best_fit_line_WS, 
         label = 'Slope = ' + '{:.2f}'.format(slope_WS) + ' km$^2$/year', color = 'blue')
plt.legend()
plt.title("Weddell Sea")
plt.ylabel('Sea ice area (km$^2$)')

plt.subplot(1,2,2)
plt.plot(mar_dates_AM, mar_values_AM, color = 'green')
plt.plot(mar_dates_AM, best_fit_line_AM, 
         label = 'Slope = ' + '{:.2f}'.format(slope_AM) + ' km$^2$/year', color = 'green')
plt.title("Amundsen Sea")
plt.ylabel('Sea ice area (km$^2$)')

#legend 
plt.legend()

# show the figure
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Problem 8.6: Interpret the Changes in Antarctic Sea Ice
# Comment on the trends observed in the Weddell vs Amundsen sea. How do they compare?
#
# The most recent IPCC Assessment Report, Chapter 9 provides a synopsis of recent research on Antarctic sea ice (in addition to many other topics). The chapter can be accessed in PDF form from a link [HERE](https://www.ipcc.ch/report/ar6/wg1/chapter/chapter-9/). What does this report say about how these trends contribute to the overall trend in Antarctic sea ice? What is one reason why Antarctic sea ice might be changing?

# %% [markdown]
# In the Weddell sea, sea ice is increasing as time increases but in the Amundsen sea, sea ice is decreasing as time decreases. The most recent IPCC assessment report states that there are regionally opposing trends and large interannual variability, which results in no significant trend in satellite-observed sea ice area from 1979 to 2020. One reason why sea ice is can increase in Antarctic is that the southern winds are increasing, which pushes the sea ice further out, causes the total area to expand. One hypothesis would be that the Weddell sea experiences these southern winds more frequently, causing sea ice to expand compared to Amundesen that does not see the expanision over time.
